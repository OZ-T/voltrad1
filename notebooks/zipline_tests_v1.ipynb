# %%
# %conda install -c Quantopian zipline
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# Examining certifi:   2%|▍                    | 3/144 [00:00<00:00, 15592.21it/s]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/5 [00:00<?, ?it/s]
#
# Finding shortest conflict path for certifi[version='>=2017.4.17']:   0%| | 0/5 [00:00<?, ?it/s]/
#
# Finding shortest conflict path for ca-certificates:  20%|▏| 1/5 [00:01<00:06,  1.54s/it]
#
# Finding shortest conflict path for ca-certificates:  40%|▍| 2/5 [00:01<00:02,  1.30it/s]-
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  40%|▍| 2/5 [00:02<00:02,  1.30it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  60%|▌| 3/5 [00:02<00:01,  1.12it/s]-
#
# Finding shortest conflict path for certifi:  60%|▌| 3/5 [00:05<00:01,  1.12it/s]
#
# Finding shortest conflict path for certifi:  80%|▊| 4/5 [00:05<00:01,  1.31s/it]-
#
# Finding shortest conflict path for certifi[version='>=2016.9.26']:  80%|▊| 4/5 [00:07<00:01,  1.31s/it]
#
# Finding shortest conflict path for certifi[version='>=2016.9.26']: 100%|█| 5/5 [00:07<00:00,  1.59s/it]/
#
#
# Comparing specs that have this dependency:  50%|█ | 1/2 [00:09<00:09,  9.49s/it]
#
# Finding conflict paths:   0%|                             | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.9.26']:   0%| | 0/3 [00:00<?, ?it/s]
#
# Finding shortest conflict path for certifi[version='>=2016.09']:  33%|▎| 1/3 [00:00<00:00, 17.02it/s]-
#
# Finding shortest conflict path for ca-certificates:  67%|▋| 2/3 [00:00<00:00, 16.77it/s]
#
# Finding shortest conflict path for ca-certificates: 100%|█| 3/3 [00:00<00:00, 25.14it/s]
#
#
# Comparing specs that have this dependency: 100%|██| 2/2 [00:09<00:00,  4.81s/it]
# Examining setuptools:  44%|████████▊           | 63/144 [00:09<02:35,  1.92s/it]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools[version='>18.0']:   0%| | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:  50%|▌| 1/2 [00:00<00:00, 26.38it/s]         |
#
#
# Comparing specs that have this dependency:  50%|█ | 1/2 [00:00<00:00,  3.17it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for setuptools:   0%|      | 0/1 [00:00<?, ?it/s]
#
#
# Examining wheel:  75%|██████████████████      | 108/144 [00:09<00:48,  1.35s/it]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for wheel:   0%|           | 0/1 [00:00<?, ?it/s]-
#
#
# Comparing specs that have this dependency:  50%|█ | 1/2 [00:02<00:02,  2.13s/it]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for wheel:   0%|           | 0/1 [00:00<?, ?it/s]\
#
#
# Examining python:  78%|██████████████████     | 113/144 [00:12<00:29,  1.04it/s] [A
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                            | 0/14 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python-dateutil[version='>=2.4.2']:   0%| | 0/14 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python-dateutil:   7%| | 1/14 [00:00<00:00, 24.11it/s]           |
#
# Finding shortest conflict path for python-dateutil[version='>=2.1']:  14%|▏| 2/14 [00:00<00:00, 12.68it/s]
#
# Examining python:  79%|██████████████████▏    | 114/144 [00:30<00:28,  1.04it/s]4 [00:00<00:00, 19.01it/s]/
#
# Finding shortest conflict path for python=2.7:  21%|▏| 3/14 [00:37<00:00, 19.01it/s]
#
# Finding shortest conflict path for python=2.7:  29%|▎| 4/14 [00:37<01:53, 11.37s/it]
#
# Finding shortest conflict path for msgpack-python:  29%|▎| 4/14 [00:37<01:53, 11.37s/it]\
#
# Finding shortest conflict path for python-dateutil[version='>=2.5.*']:  36%|▎| 5/14 [01:18<01:42, 11.37s/it]
#
# Finding shortest conflict path for python-dateutil[version='>=2.5.*']:  43%|▍| 6/14 [01:18<01:52, 14.09s/it]/
#
# Finding shortest conflict path for python[version='>=3.5']:  43%|▍| 6/14 [01:20<01:52, 14.09s/it]
#
# Finding shortest conflict path for python[version='>=3.5']:  50%|▌| 7/14 [01:20<01:11, 10.26s/it]\
#
# Finding shortest conflict path for python[version='>=2.7,<2.8.0a0']:  50%|▌| 7/14 [01:21<01:11, 10.26s/it]
#
# Finding shortest conflict path for python[version='>=2.7,<2.8.0a0']:  57%|▌| 8/14 [01:21<00:46,  7.70s/it]|
#
# Finding shortest conflict path for python:  57%|▌| 8/14 [01:22<00:46,  7.70s/it]
#
# Finding shortest conflict path for python:  64%|▋| 9/14 [01:22<00:27,  5.46s/it]\
#
# Finding shortest conflict path for python=3.5:  64%|▋| 9/14 [01:23<00:27,  5.46s/it]
#
# Finding shortest conflict path for python=3.5:  71%|▋| 10/14 [01:23<00:16,  4.21s/it]|
#
# Finding shortest conflict path for python=3.7:  71%|▋| 10/14 [01:23<00:16,  4.21s/it]
#
# Finding shortest conflict path for python=3.7:  79%|▊| 11/14 [01:23<00:08,  2.98s/it]|
#
# Finding shortest conflict path for python[version='>=3.5,<3.6.0a0']:  79%|▊| 11/14 [03:13<00:08,  2.98s/it]
#
# Finding shortest conflict path for python[version='>=3.5,<3.6.0a0']:  86%|▊| 12/14 [03:13<01:10, 35.05s/it]
#
# Finding shortest conflict path for python[version='<=3.3']:  86%|▊| 12/14 [03:13<01:10, 35.05s/it]         |
#
# Finding shortest conflict path for python-editor[version='>=0.3']:  93%|▉| 13/14 [03:50<00:35, 35.05s/it]
#
# Finding shortest conflict path for python-editor[version='>=0.3']: 100%|█| 14/14 [03:50<00:00, 30.05s/it]\
#
#
# Comparing specs that have this dependency:  50%|▌| 1/2 [03:54<03:54, 234.14s/it]
#
# Finding conflict paths:   0%|                             | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python[version='>=3.7,<3.8.0a0']:   0%| | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for python=3.7:  50%|▌| 1/2 [00:00<00:00, 5216.80it/s]
#
#
# Examining pip:  83%|█████████████████████▋    | 120/144 [04:06<05:53, 14.72s/it]
# Comparing specs that have this dependency:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Finding conflict paths:   0%|                             | 0/2 [00:00<?, ?it/s]
#
# Finding shortest conflict path for pip:   0%|             | 0/2 [00:00<?, ?it/s]-
#
# Finding shortest conflict path for pip[version='>=7.1.0']:  50%|▌| 1/2 [00:01<00:01,  1.52s/it]
# Finding shortest conflict path for pip[version='>=7.1.0']: 100%|█| 2/2 [00:01<00:00,  1.32it/s]
#
#
# Comparing specs that have this dependency:  50%|█ | 1/2 [00:01<00:01,  1.56s/it]
#
# Finding conflict paths:   0%|                             | 0/1 [00:00<?, ?it/s]
#
# Finding shortest conflict path for pip:   0%|             | 0/1 [00:00<?, ?it/s]
#
#
#                                                                                failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
#
#
# Package wheel conflicts for:
# zipline -> pip[version='>=7.1.0'] -> wheel
# python=3.7 -> pip -> wheel
# Package certifi conflicts for:
# python=3.7 -> pip -> setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# Package pip conflicts for:
# zipline -> python=2.7 -> pip
# python=3.7 -> pip
# zipline -> pip[version='>=7.1.0']
# Package python conflicts for:
# python=3.7
# Package setuptools conflicts for:
# zipline -> setuptools[version='>18.0']
# python=3.7 -> pip -> setuptools
# zipline -> matplotlib -> setuptools
# Package ca-certificates conflicts for:
# python=3.7 -> openssl[version='>=1.1.1a,<1.1.2a'] -> ca-certificates
# zipline -> requests -> ca-certificates
# Package python-dateutil conflicts for:
# zipline -> python-dateutil[version='>=2.4.2']
# Package msgpack-python conflicts for:
# zipline -> bcolz[version='>=0.12.1'] -> dask[version='>=0.9.0'] -> bokeh[version='>=0.13.0'] -> msgpack-python
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from zipline.api import order, record, symbol


def initialize(context):
    pass


def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))
